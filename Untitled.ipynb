# %%
import json
import pickle
from functools import reduce
from collections import defaultdict

# %%
class entity:
    def __init__(self, recipe):
        self.recipe = recipe
        self.ingredient = [x for x in recipe["food_ingredients"]]
        self.number = [0.0 for x in recipe["food_ingredients"]]
        self.unit = ["TBD" for x in recipe["food_ingredients"]]
        self.entities = ["TBD" for x in recipe["food_ingredients"]]
#         self.failure
#         self.recipe_triple = []
    def get_nlpres(self, nlp_output, index):
        if not nlp_output:
            self.number[index]="TBD"
            self.unit[index] = "TBD"
            self.entities[index] = "TBD"
#             print("")
            return
        res = 0.0
        for v in nlp_output:
            if v[1] != 'CARDINAL' and v[1] != "QUANTITY":
#                 print(v)
                pass
            elif v[1] == "CARDINAL":
                vals = v[0].split()
#                 res = 0.0
                for _ in vals:
                    try:
                        res+=eval(_)
                    except:
                        break
                self.number[index]=res
        
#                 self.unit.append("TBD")
#                 self.entities.append("TBD")
            else:
                vals = v[0].split()
#                 res = 0.0
                for _ in vals:
                    try:
                        res += eval(_)
                    except:
                        self.unit[index] = _
                        break
                self.number[index] = res
#                 self.entities.append("TBD")
            #TBD as default since cannot find

# %%
recipes[0].unit
# Out:
# ['cup', 'cup', 'teaspoon', 'cup', 'teaspoon', 'cup', 'cup', 'DEFAULT']

# %%
recipes = pickle.load(open("./third_round_extraction.pkl", "rb"))

# %%
dir(recipes[0])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'entities',
#  'get_nlpres',
#  'ingredient',
#  'number',
#  'recipe',
#  'unit']

# %%
all_units = reduce(lambda x,y:x.union(y) ,(map(lambda x: set(x.unit), recipes)))

# %%
len(all_units)
# Out:
# 14

# %% [markdown]
# ## Solving units
# ### First Round Res:
#
# "4x4-inch", "1-inch", "1/2-inch", "1/8-inch", "12-inch", "2-inch", "degree", "f/45", "fluid", "12x12", "half"  -> remove inches out,in nlp again
#
# "caramel", "chicken", "cloves","garlic", "graham", "ice", "maraschino", "pint", "portobello", "whole", "(" -> DEFAULT
#
# "cube", 'cup', "gallon", "gram","liter", "milliliter", "oz", "pound", "quart", "tablespoon", "teaspoon"
#
# "ounce" to "oz"
#
# "not valid", "red", "yellow" Remove
#
# "skinless" -> in entity, change it to "chicken breast halves", in unit, change to default and add entities as "chicken breast halves"

# %%
all_foods = reduce(lambda x,y:x.union(y) ,(map(lambda x: set(x.entities), recipes)))

# %%
# statistic:
lenthoffoods = defaultdict(set)
for a in all_foods:
    lenthoffoods[len(a.split())].add(a)

# %%
lenthoffoods.keys()
# Out:
# dict_keys([0, 3, 4, 2, 5, 8, 7, 1, 6, 9, 10, 11])

# %%
len(lenthoffoods[7])
# Out:
# 53

# %%
lenthoffoods[11]
# Out:
# {'package seasoned crouton such new brand texas toast sea salt pepper'}

# %%
lenthoffoods[10]
# Out:
# {'fat free creamy salad dressing fat free miracle whip tm',
#  'g tub philadelphia savoury garlic cooking creme cream cheese product',
#  'garlic flavor bite size bagel chip regular size bagel chip'}

# %%
lenthoffoods[0]
# Out:
# {''}

# %%
lenthoffoods[7]
# Out:
# {'bag eye recipe ready pizza supreme blend',
#  'bag white cheddar kettle style potato chip',
#  'box chicken flavor dry bread stuffing mix',
#  'box dry corn muffin mix such jiffy',
#  'brandy base orange liqueur such grand marnier',
#  'citrus flavor energy drink red bull ™',
#  'cup blue green fruit flavor candy such',
#  'dash hot pepper sauce such frank redhot',
#  'dash hot pepper sauce texas pete ™',
#  'drain hot mild pickle banana pepper ring',
#  'envelope fleischmann pizza crust yeast rapidrise yeast',
#  'fluid ounce gran gala triple orange liqueur',
#  'fluid ounce triple sec orange flavor liqueur',
#  'foil wrap milk chocolate piece such hershey',
#  'frozen bite size potato nugget such tater',
#  'g package naan bread bread g package',
#  'jar real bacon piece such hormel ™',
#  'light rye flour such bob red mill',
#  'low fat greek style yogurt such fage',
#  'ounce bottle buffalo wing sauce such frank',
#  'ounce cream mushroom soup regular % sodium',
#  'ounce envelope fleischmann pizza crust yeast yeast',
#  'ounce jar chunky spaghetti sauce such monte',
#  'ounce package devil food cake mix pudding',
#  'ounce package dry italian salad dressing mix',
#  'ounce package german chocolate cake mix pudding',
#  'ounce package prebaked pizza crust such boboli',
#  'ounce package room temperature fresh pizza dough',
#  'ounce pulp free pure premium orange juice',
#  'ounce reduce fat sharp cheddar cheese cube',
#  'ounce sweeten cream coconut such coco lopez',
#  'ounce tomato clam juice cocktail such clamato',
#  'ounce tomato green chile pepper such ro*tel',
#  'package candy coat milk chocolate piece such',
#  'package chicken flavor dry bread stuffing mix',
#  'package double ready use pie crust such',
#  'package instant sugar free vanilla pudding mix',
#  'package long grain wild rice seasoning packet',
#  'package milk chocolate candy kiss such hershey',
#  'package shred cheddar monterey jack cheese blend',
#  'package white chocolate square white baking bar',
#  'package whole wheat macaroni such smart taste',
#  'pastry double crust pie footnote recipe link',
#  'pinch salt free seasoning blend such dash',
#  'pouch progresso recipe creamy cheese cooking sauce',
#  'progresso italian style panko crispy bread crumb',
#  'recipe pastry double crust deep dish pie',
#  'reduce fat process cheese food such velveeta',
#  'shred % milk cheddar cheese such kraft',
#  'shred white yellow cheese such mozzarella cheddar',
#  'tablespoon vegan cream cheese substitute such tofutti',
#  'teaspoon cajun seasoning blend such tony chachere',
#  'white confectioner coat premium white chocolate chip'}

# %% [markdown]
# ### Solving entities
# 1. length 0,7,8,9,10,11 remove

# %%
len(recipes)
# Out:
# 3828

# %%
list(lenthoffoods[2])[5]
# Out:
# 'fuji apple'

# %%
from copy import copy
reduced_food = copy(lenthoffoods)
rm_list = [0,7,8,9,10,11]
for r in rm_list:
    del reduced_food[r]

# %%
"ounce" in lenthoffoods[1]
# Out:
# False

# %% [markdown]
# ### TODO
# 1. Remove units word from all list
# 2. Only keeps Noun in 1-length list
# 3. TOBECONTINUED

# %%
import spacy
import regex
import json
from collections import Counter
nlp =  spacy.load('en_core_web_lg')
from spacy.lemmatizer import Lemmatizer
from spacy.lang.en import LEMMA_INDEX, LEMMA_EXC, LEMMA_RULES
from spacy.tokenizer import Tokenizer
Tokenizer = Tokenizer(nlp.vocab)
Lemmatizer = Lemmatizer(LEMMA_INDEX, LEMMA_EXC, LEMMA_RULES)

# %%
all_units.add("ounce")
bad_words = set(list(all_units)+list({"1/4-inch", "4x4-inch", "1-inch", "1/2-inch", "1/8-inch", "12-inch", "2-inch", "degree", "f/45", "fluid", "12x12", "half", "degree degree"}))

# %%
bad_words
# Out:
# {'1-inch',
#  '1/2-inch',
#  '1/4-inch',
#  '1/8-inch',
#  '12-inch',
#  '12x12',
#  '2-inch',
#  '4x4-inch',
#  'DEFAULT',
#  'cube',
#  'cup',
#  'degree',
#  'degree degree',
#  'f/45',
#  'fluid',
#  'gallon',
#  'gram',
#  'half',
#  'inch',
#  'liter',
#  'milliliter',
#  'not valid',
#  'ounce',
#  'oz',
#  'pound',
#  'quart',
#  'tablespoon',
#  'teaspoon'}

# %%
tmp = copy(reduced_food[1])
len(tmp)
# Out:
# 219

# %%
for t in tmp:
    if t in bad_words:
        reduced_food[1].remove(t)

# %%
def writeres(length, l):
    file = "./"+str(length)+".txt"
    with open(file, "w") as f:
        for v in l:
            f.write(v)
            f.write("\n")

# %%
out_1 = []
for r in reduced_food[1]:
    tmp=nlp(r)
    for token in tmp:
        if token.tag_ == "NN":
            out_1.append(token.text)
len(out_1)
# Out:
# 182

# %%
writeres(1,out_1)

# %%
# finished lenth 1 items, begin with more than 2
len(reduced_food[2])
# Out:
# 1171

# %%
outputs = set()
for key, value in reduced_food.items():
    if key != 1:
        tmp = copy(value)
        for t in tmp:
            res = []
            for v in t.split():
                if v not in bad_words:
                    res.append(v)
            if res:
                outputs.add(" ".join(res))

# %%
outputs = set(list(outputs)+list(out_1))

# %%
len(outputs)
# Out:
# 3973

# %%
# add to 1-itmset
outputs_dict = defaultdict(set)
for o in outputs:
    outputs_dict[len(o.split())].add(o)

# %%
outputs_dict.keys()
# Out:
# dict_keys([3, 4, 2, 5, 1, 6])

# %%
for k, v in outputs_dict.items():
    writeres(k, v)

# %%
len(outputs[2])
# Out:
# 1139

# %%
len(outputs[3])
# Out:
# 1652

# %%
len(outputs[4])
# Out:
# 1013

# %%
len(outputs[5])
# Out:
# 415

# %%
len(outputs[6])
# Out:
# 155

# %%
outputs[3]
# Out:
# {'small green onion',
#  'cold water optional',
#  'package vegetarian burger',
#  'jar apple jelly',
#  'english walnut',
#  'coconut oil',
#  'package cocktail sausage',
#  'peach schnapps',
#  'shred romano cheese',
#  'thin slice ham',
#  'peanut butter optional',
#  'twist lime zest',
#  'container alfredo sauce',
#  'package caramel',
#  'carton sour cream',
#  'solid pack pumpkin',
#  'chicken breast tenderloin',
#  'slice smoke turkey',
#  'egg white optional',
#  'chop pecan optional',
#  'ground paprika',
#  'low fat yogurt',
#  'cheddar cheese soup',
#  'artichoke bottom',
#  'shred roasted chicken',
#  'fresh dill weed',
#  'english cucumber peel',
#  'fresno chile pepper',
#  'jigger gin',
#  'sweet bread roll',
#  'extra large onion',
#  'green bell pepper',
#  'slice swiss cheese',
#  'pizza dough',
#  'package ground sausage',
#  'package frozen raspberry',
#  'light sour cream',
#  'package silken tofu',
#  'pork baby rib',
#  'maraschino cherry garnish',
#  'serrano chile pepper',
#  'shred chinese cabbage',
#  'ground nutmeg optional',
#  'fresh grapefruit juice',
#  'lean ground sirloin',
#  'orange zest',
#  'creme cacao',
#  'package rice noodle',
#  'large bake potato',
#  'butter room temperature',
#  'uncooked brown rice',
#  'unbaked pizza crust',
#  'container peach yogurt',
#  'spicy italian sausage',
#  'large pita bread',
#  'jigger tequila',
#  'chocolate candy bar',
#  'frozen strawberry syrup',
#  'dry thyme leaf',
#  '12-inch pizza crust',
#  'limoncello liqueur',
#  'ground cardamom',
#  'cajun seasoning',
#  'light cream cheese',
#  'gumbo file powder',
#  'cotija cheese',
#  'stuff green olive',
#  'peel cubed potato',
#  'honeydew melon peel',
#  'slice hard salami',
#  'chicken soup base',
#  'apple pie spice',
#  'ham bone meat',
#  'almond flavor syrup',
#  'chop pimento pepper',
#  'strawberry flavor yogurt',
#  'dill pickle spear',
#  'flatbread pizza crust',
#  'orange extract',
#  'dry barbeque rub',
#  'sweet italian sausage',
#  'pomegranate seed optional',
#  'package uncooked macaroni',
#  'jigger rum',
#  'lemon extract',
#  'crush corn flake',
#  'pinch dry marjoram',
#  'ground flax seed',
#  'package dry macaroni',
#  'buffalo mozzarella cheese',
#  'fresh lime juice',
#  'pure maple syrup',
#  'sift confectioner sugar',
#  'ground beef chuck',
#  'fillet prime rib',
#  'slice black olive',
#  'dark sweet cherry',
#  'swiss cheese',
#  'natural peanut butter',
#  'sift purpose flour',
#  'package elbow macaroni',
#  'bone turkey breast',
#  'leaf lettuce optional',
#  'tomato garlic onion',
#  'fat cottage cheese',
#  'fresh asparagus',
#  'cheap beer',
#  'slice green cabbage',
#  'bottled steak sauce',
#  'sunflower seed oil',
#  'package ramen noodle',
#  'lamb chop thick',
#  'slice cantaloupe',
#  'toast sliced almond',
#  'black forest ham',
#  'peel diced potato',
#  'pinch baking soda',
#  'small sugar pumpkin',
#  'frozen unsweetened strawberry',
#  'jar taco sauce',
#  'slice salami',
#  'macaroni pasta choice',
#  'pinch salt optional',
#  'powdered lemonade mix',
#  'self rise cornmeal',
#  'chicken bouillon powder',
#  'pinch ground nutmeg',
#  'fresh pizza dough',
#  'coffee flavor liqueur',
#  '% milk',
#  'granulate sugar decoration',
#  'slice genoa salami',
#  'baby spinach leaf',
#  'package white chocolate',
#  'bunch green onion',
#  'carton chicken broth',
#  'italian sausage',
#  'horseradish optional',
#  'uncooked white rice',
#  'biscuit baking mix',
#  'butter flavor extract',
#  'cooking sherry',
#  'toast sesame seed',
#  'sourdough starter',
#  'chop ham',
#  'milk chocolate',
#  'white sugar decoration',
#  'whey protein powder',
#  'mince fresh garlic',
#  'gorgonzola cheese',
#  'purpose flour coating',
#  'package corn kernel',
#  'small garlic clove',
#  'flour matzo meal',
#  'slice prosciutto',
#  'fresh oregano leaf',
#  'cream milk',
#  'bake pizza crust',
#  'prepared pesto sauce',
#  'boneless pork chop',
#  'malibu rum',
#  'chop cauliflower',
#  'large cucumber peel',
#  'prepared pizza dough',
#  'pinch dry oregano',
#  'red wine optional',
#  'prepared pizza crust',
#  'package brownie mix',
#  'bulb garlic clove',
#  'julienne slice carrot',
#  'cook crabmeat',
#  'bottle beer',
#  'rice vermicelli',
#  'pita bread pocket',
#  'season bread crumb',
#  'jar pasta sauce',
#  'old thick chunky',
#  'dry cranberry',
#  'whole cardamom pod',
#  'rotisserie roast chicken',
#  'pack brown sugar',
#  'parmesan cheese',
#  'jar marshmallow cream',
#  'chocolate chip optional',
#  'fat milk',
#  'celery salt',
#  'clove fresh garlic',
#  'red wine vinegar',
#  'container cottage cheese',
#  'dark rum',
#  'dry elbow macaroni',
#  'corn chex cereal',
#  'dry penne pasta',
#  'fruit preserve',
#  'cayenne pepper',
#  'box uncooked rigatoni',
#  'package saltine cracker',
#  'cubed smoke sausage',
#  'mince garlic optional',
#  'eye round',
#  'lean ground lamb',
#  'granny smith apple',
#  'sweet sour mix',
#  'lemon pepper optional',
#  'triple sec liqueur',
#  'apple juice',
#  'wheat chex cereal',
#  'shiitake mushroom',
#  'corkscrew shape pasta',
#  'french sandwich roll',
#  'red bell pepper',
#  'cranberry juice',
#  'semisweet chocolate piece',
#  'large sweet onion',
#  'aged balsamic vinegar',
#  'chinese rice wine',
#  'medium head cabbage',
#  'roasted peanut',
#  'pizza crust',
#  'sirloin tip roast',
#  'slice slice ham',
#  'mexican cheese blend',
#  'beef broth',
#  'dry red lentil',
#  'fancy molass',
#  'shred cheddar cheese',
#  'tomato paste optional',
#  'cubed seed watermelon',
#  'pie fill',
#  'silver dragee candy',
#  'ground chia seed',
#  'fresh frozen vegetable',
#  'pint heavy cream',
#  'vegetable oil fry',
#  'container vanilla frosting',
#  'self rise flour',
#  'irish cream liqueur',
#  'basil pesto sauce',
#  'dry dill',
#  'bunch fresh spinach',
#  'thin slice bacon',
#  'package biscuit dough',
#  'jar ragu cheesy',
#  'venison stew meat',
#  'chop tomato optional',
#  'land o butter',
#  'old fashioned oats',
#  'bourbon whiskey such',
#  'heart romaine lettuce',
#  'grated provolone cheese',
#  'fresh cranberry',
#  'red pepper flake',
#  'fluid gin',
#  'bottle ranch dressing',
#  'cod fillet',
#  'apple pie fill',
#  'dry soba noodle',
#  'slice pepperjack cheese',
#  'fine salt',
#  'pork shoulder roast',
#  'barbecue sauce',
#  'chop toast pecan',
#  'cinnamon oil',
#  'raw spanish peanut',
#  'boneless beef roast',
#  'pure vanilla extract',
#  'fresh jalapeno pepper',
#  'seedless green grape',
#  'slice cook ham',
#  'shred carrot optional',
#  'dark sesame oil',
#  'thai peanut sauce',
#  'lime wedge garnish',
#  'salt black pepper',
#  'fresh dill',
#  'instant rice',
#  'frozen pizza dough',
#  'dry milk powder',
#  'head fresh cauliflower',
#  'hull fresh strawberry',
#  'fresh italian sausage',
#  'chop cherry',
#  'ginger ale soda',
#  'mini sandwich roll',
#  'frozen red raspberry',
#  'yellow food coloring',
#  'stem piece',
#  'heavy whipping cream',
#  'white daikon radish',
#  'vegetable broth stock',
#  'slice ham',
#  'heavy cream',
#  'thin pretzel stick',
#  'package smoke sausage',
#  'pumpkin seed optional',
#  'package neufchatel cheese',
#  'orange juice',
#  'dry oregano',
#  'fresh cilantro',
#  'shred pepperjack cheese',
#  'style pasta sauce',
#  'uncooked orzo pasta',
#  'chop onion optional',
#  'cherry grenadine syrup',
#  'shred lettuce romaine',
#  'beef tenderloin roast',
#  'crush red pepper',
#  'grated romano cheese',
#  'small black olive',
#  'egg room temperature',
#  'package acini pasta',
#  'jalapeno chile pepper',
#  'uncooked medium shrimp',
#  'grate orange peel',
#  'slice bacon',
#  'chocolate soy milk',
#  'unbaked pie crust',
#  'sour cream optional',
#  'fluid rum',
#  'dash garlic powder',
#  'ground turkey',
#  'balsamic vinegar',
#  'dijon mustard',
#  'fresh peach pit',
#  'brew black tea',
#  'caraway seed',
#  'bean sprout optional',
#  'raspberry flavor liqueur',
#  'mission fajita flour',
#  'cornflake cereal crumb',
#  'nonfat plain yogurt',
#  'pina colada mix',
#  'tomato juice',
#  'chai tea mix',
#  'diced cook ham',
#  'quarter cherry tomato',
#  'package fettuccini pasta',
#  'dash grenadine syrup',
#  'poppy seed',
#  'leaf kale leaf',
#  'pecorino romano cheese',
#  'soft margarine',
#  'anchovy paste optional',
#  'pineapple juice',
#  'chop parsley',
#  'fresh ginger root',
#  'lemon zest',
#  'mince fresh sage',
#  'ginger garlic paste',
#  'chop black olive',
#  'dill pickle juice',
#  'box uncooked macaroni',
#  'cub papaya optional',
#  'imitation crabmeat',
#  'dry currant raisin',
#  'prepared pizza sauce',
#  'uncooked lasagna noodle',
#  'mash overripe banana',
#  'slice provolone cheese',
#  'green onion',
#  'fresh slice mushroom',
#  'package fusilli pasta',
#  'white rum such',
#  'ketchup optional',
#  'confectioner sugar dusting',
#  'sharp cheddar cheese',
#  'fluid cointreau',
#  'olive oil',
#  'white wine vinegar',
#  'mexican vanilla extract',
#  'jigger milk',
#  'diced roma tomato',
#  'package cavatelli pasta',
#  'beef bouillon',
#  'white corn',
#  'beef bouillon granule',
#  'white pepper',
#  'chop chive',
#  'box penne pasta',
#  'chocolate confectioner coating',
#  'square bittersweet chocolate',
#  'jar artichoke heart',
#  'creole cajun seasoning',
#  'apple schnapps',
#  'bottle port wine',
#  'slice fresh strawberry',
#  'pint spice rum',
#  'raspberry liqueur',
#  'slice corned beef',
#  'seasoning salt',
#  'unsalted sunflower seed',
#  'fat free milk',
#  'shred havarti cheese',
#  'sesame seed',
#  'grate fresh ginger',
#  'slice fresh mushroom',
#  'dash ground nutmeg',
#  'jumbo pasta shell',
#  'pinch ground allspice',
#  'baked pie crust',
#  'packet artificial sweetener',
#  'salmon fillet',
#  'fresh broccoli',
#  'pearl israeli couscous',
#  'red onion',
#  'burgundy wine',
#  'smoke salmon',
#  'worcestershire sauce',
#  'red black licorice',
#  'package sliver almond',
#  'unbaked pie shell',
#  'fresh parsley',
#  'uncooked penne pasta',
#  'sprig fresh rosemary',
#  'unsweetened almond milk',
#  'cocoa powder',
#  'large cook shrimp',
#  'pinquito pinto bean',
#  'banana liqueur',
#  'container chocolate frosting',
#  'light rum',
#  'package miniature marshmallow',
#  'chipotle chili powder',
#  'large navel orange',
#  'chia seed optional',
#  'longhorn cheddar cheese',
#  'lemon juice',
#  'butter bean',
#  'seasoned bread crumb',
#  'coffee liqueur',
#  'whole wheat tortilla',
#  'buttermilk baking mix',
#  'small gravenstein apple',
#  'rice wrapper diameter',
#  'large tomato peel',
#  'package pepperoni sausage',
#  'fresh marjoram leaf',
#  'package fresh mozzarella',
#  'pinch salt pepper',
#  'package spinach leaf',
#  'green candy pineapple',
#  'confectioner sugar rolling',
#  'jar slice mushroom',
#  'slice bacon optional',
#  'chocolate hazelnut spread',
#  'blue food coloring',
#  'mince fresh onion',
#  'chocolate cookie crumb',
#  'beef hot dog',
#  'strip turkey bacon',
#  'plain bread crumb',
#  'dry basil optional',
#  'chop walnut',
#  'apple peel',
#  'large black olive',
#  'unsweetened flake coconut',
#  'peach heavy syrup',
#  'fresh strawberry optional',
#  'almond extract',
#  'melon liqueur',
#  'fusilli spiral pasta',
#  'red pepper',
#  'package slice pepperoni',
#  'grated mozzarella cheese',
#  'portobello mushroom cap',
#  'grapefruit juice',
#  'package vanilla wafer',
#  'pizza sauce',
#  'medium fresh tomato',
#  'bottle clam juice',
#  'crush saltine cracker',
#  'jar chop pimento',
#  'rice wine vinegar',
#  'chicken breast halves',
#  'pinch dry thyme',
#  'seasoned salt',
#  'fresh parsley optional',
#  'small boil onion',
#  'vegetable shortening',
#  'tomato green chile',
#  'box confectioner sugar',
#  'oyster sauce',
#  'package green pea',
#  'yellow mustard',
#  'garlic powder',
#  'white chocolate chip',
#  'dijon style mustard',
#  'unseasoned rice vinegar',
#  'bar milk chocolate',
#  'scotch whiskey',
#  'grated carrot optional',
#  'sesame seed optional',
#  'dill pickle relish',
#  'heinz tomato ketchup',
#  'unsalted soda cracker',
#  'package frozen corn',
#  'strip orange peel',
#  'package mixed vegetable',
#  'dry parsley',
#  'penne pasta',
#  'whole fresh mushroom',
#  'fresh bean',
#  'whole allspice berry',
#  'cavatappi corkscrew pasta',
#  'plain pop popcorn',
#  'large yellow onion',
#  'sweet pepper',
#  'toast sliver almond',
#  'chop peanut optional',
#  'durkee ground mustard',
#  'mixed vegetable',
#  'salad shrimp',
#  'jar maraschino cherry',
#  'farfalle tie pasta',
#  'dash hot sauce',
#  'cold water',
#  'uncooked pearl barley',
#  'ground cayenne pepper',
#  'mince green onion',
#  'ground ginger',
#  'pizza crust dough',
#  'fresh basil leaf',
#  'package cornbread mix',
#  'pit sour cherry',
#  'whole coffee bean',
#  'potato juice',
#  'spice onion powder',
#  'hot chile paste',
#  'premium tequila',
#  'hot chili powder',
#  'chocolate kiss candy',
#  'dill pickle slice',
#  'wheat germ optional',
#  'process cheese food',
#  'package crescent roll',
#  'ancho chile powder',
#  'crisp rice cereal',
#  'vanilla wafer crumb',
#  'new red potato',
#  'dash bitter optional',
#  'envelope unflavored gelatin',
#  'chop potato',
#  'package slice salami',
#  'peanut oil fry',
#  'large cook skinless',
#  'rub sage',
#  'package rotini pasta',
#  'medium yellow pepper',
#  'smooth peanut butter',
#  'ice optional',
#  'container greek yogurt',
#  'package rotelle pasta',
#  'pinch ground cinnamon',
#  'panko bread crumb',
#  'orange flavor liqueur',
#  'deli ham',
#  'package frozen broccoli',
#  'large sweet potato',
#  'cub cheddar cheese',
#  'pumpkin pie fill',
#  'slice jalapeno pepper',
#  'cubed stew meat',
#  'whole grain mustard',
#  'plain yogurt',
#  'tomato puree',
#  'sprig fresh parsley',
#  'crush gingersnap cookie',
#  'vegetarian worcestershire sauce',
#  'bunch mint leaf',
#  'ground cumin optional',
#  'sift cake flour',
#  'lemon flavor yogurt',
#  'package dry lentil',
#  'maple flavor extract',
#  'frozen whole strawberry',
#  'manicotti pasta',
#  'frozen chop spinach',
#  'slice rye bread',
#  'cream style corn',
#  'ground dry thyme',
#  'beef chuck',
#  'pinch dry basil',
#  'potato peel cubed',
#  'chop cook turkey',
#  'dark rum such',
#  'grind black pepper',
#  'dash garlic salt',
#  'round hard roll',
#  'wheat germ',
#  'root beer',
#  'flavor fruit jam',
#  'soy milk',
#  'dry dill weed',
#  'ground cinnamon',
#  'pint sour cream',
#  'leaf fresh basil',
#  'slice carrot',
#  'lime juice',
#  'large jalapeno pepper',
#  'grate romano cheese',
#  'cayenne pepper optional',
#  'chill pineapple juice',
#  'blueberry frozen fresh',
#  'real maple syrup',
#  'garlic chili sauce',
#  'brown sugar',
#  'ripe avocado peel',
#  'other sweet onion',
#  'crumble feta cheese',
#  'greek seasoning',
#  'whole roasted almond',
#  'large ripe tomato',
#  'chow noodle',
#  'lemon grass optional',
#  'mash sweet potato',
#  'sour mix',
#  'pork tenderloin',
#  'crush vanilla wafer',
#  'slice gruyere cheese',
#  'medium sugar pumpkin',
#  'medium apple peel',
#  'small white onion',
#  'dry rosemary',
#  'french fry onion',
#  'dice green onion',
#  'crush clove optional',
#  'package parmesan cheese',
#  'dice carrot',
#  'whip heavy cream',
#  'easy pizza crust',
#  'slice pepperoni sausage',
#  'season rice vinegar',
#  'piece candy corn',
#  'triple berry vodka',
#  'chop dill pickle',
#  'shred corned beef',
#  'log goat cheese',
#  'canadian whiskey',
#  'green pepper',
#  'carbonated water',
#  'wild rice',
#  'loaf italian bread',
#  'extra large egg',
#  'baking powder',
#  'peanut butter chip',
#  'chop fresh parsley',
#  'garlic pepper seasoning',
#  'dark beer',
#  'pinch cayenne pepper',
#  'good quality vodka',
#  'chop tomato',
#  'medium yellow onion',
#  'mince crabmeat',
#  'small mini pretzel',
#  'package frozen cheese',
#  'smoke paprika',
#  'dash salt pepper',
#  'thin slice cucumber',
#  'stone ground mustard',
#  'vanilla flavor vodka',
#  'andouille sausage',
#  'curry powder',
#  'shred provolone cheese',
#  'chop cook chicken',
#  'bulk pork sausage',
#  'coconut milk',
#  'firm tofu',
#  'dry thyme',
#  'ground mustard',
#  'fresh italian parsley',
#  'tomato sauce',
#  'small frozen banana',
#  'cubed shred ham',
#  'mash potato optional',
#  'white vinegar',
#  'leaf romaine lettuce',
#  'buffalo wing sauce',
#  'crush butter cracker',
#  'whole wheat flour',
#  'powder protein supplement',
#  'jigger vodka',
#  'dry italian seasoning',
#  'season tomato sauce',
#  'stick unsalted butter',
#  'flank steak',
#  'whole tomato liquid',
#  'sherry vinegar',
#  'pint grape tomato',
#  'sunflower seed',
#  'pork butt roast',
#  'tapenade olive spread',
#  'oil deep frying',
#  'toast walnut piece',
#  'cubed cook ham',
#  'dough such pillsbury',
#  'pint fresh strawberry',
#  'beef stew meat',
#  'semisweet chocolate morsel',
#  'olive oil fry',
#  'dry vermouth',
#  'dry bread crumb',
#  'peppermint extract',
#  'white rum',
#  'greek salad dressing',
#  'peppermint candy cane',
#  'mahi mahi fillet',
#  'light brown sugar',
#  'uncooked ditalini pasta',
#  'quarter strawberry',
#  'package cheddar cheese',
#  'whole tomato',
#  'chicken breast meat',
#  'leftover grill chicken',
#  'italian salami',
#  'cook spaghetti',
#  'crush potato chip',
#  'dill seed',
#  'pinch ground cumin',
#  'dijon mustard optional',
#  'tomato soup',
#  'hot pepper sauce',
#  'grape cherry tomato',
#  'slice peel peach',
#  'crescent dinner roll',
#  'cold brew coffee',
#  'unsalted butter chill',
#  'hot italian sausage',
#  'freeze whip topping',
#  'chop cucumber',
#  'red cooking wine',
#  'slice roast turkey',
#  'cream tartar',
#  'creamy peanut butter',
#  'jar marshmallow creme',
#  'large ripe banana',
#  'diced apple peel',
#  'slice ripe tomato',
#  'toast pine nut',
#  'container jumbo biscuit',
#  'small avocado peel',
#  'sweet vermouth',
#  'ground coriander seed',
#  'roasted red pepper',
#  'jar basil pesto',
#  'melt butter',
#  'dash worcestershire sauce',
#  'anaheim chile pepper',
#  'vanilla vodka',
#  'kidney bean',
#  'asiago cheese',
#  'xanthan gum',
#  'slice sourdough bread',
#  'chicken breast half',
#  'green enchilada sauce',
#  'hungarian sweet paprika',
#  'french bread baguette',
#  'spicy barbeque sauce',
#  'package french fry',
#  'pint ricotta cheese',
#  'white sugar optional',
#  'bottle italian dressing',
#  'slice dill pickle',
#  'square unsweetened chocolate',
#  'feta cheese',
#  'prepared honey mustard',
#  'dry basil leaf',
#  'chili pepper flake',
#  'cream coconut',
#  'pie filling',
#  'pickle cauliflower floret',
#  'tub vanilla yogurt',
#  'medium red potato',
#  'package bean mixture',
#  'package mini marshmallow',
#  'parmigiano reggiano cheese',
#  'slice cheddar cheese',
#  'ground dry mustard',
#  'pinch sea salt',
#  'season salt',
#  'large egg yolk',
#  'package garlic crouton',
#  'head fresh dill',
#  'pinch fenugreek seed',
#  'candy citron',
#  'kentucky bourbon',
#  'piece fresh ginger',
#  'unpeeled red apple',
#  'white chocolate',
#  'package blue cheese',
#  'fresh mango',
#  'vegetable stock',
#  'package cream cheese',
#  'package kielbasa sausage',
#  'kikkoman ponzu lime',
#  'unsweetened cocoa powder',
#  'chocolate fudge top',
#  'slice pepperoncini pepper',
#  'diced tomato optional',
#  'package frozen spinach',
#  'large fresh strawberry',
#  'grind unsalted cashews',
#  'shred iceberg lettuce',
#  'ready pizza crust',
#  'package egg noodle',
#  'soft flour tortilla',
#  'fresh chive',
#  'bulk italian sausage',
#  'diced green chile',
#  'sweet pickle juice',
#  'cook shrimp',
#  'dash ground cinnamon',
#  'square white chocolate',
#  'garlic salt optional',
#  'bite size pretzel',
#  'slice italian bread',
#  'black eyed pea',
#  'whole black peppercorn',
#  'yellow onion',
#  'french salad dressing',
#  'clove crush garlic',
#  '% buttermilk',
#  'sun dry tomato',
#  'dry brown lentil',
#  'drain olive',
#  'jar spaghetti sauce',
#  'alfredo sauce',
#  'pinch seasoned salt',
#  'mince fresh rosemary',
#  'mash ripe banana',
#  'crush pineapple juice',
#  'red candy pineapple',
#  'ground cumin',
#  'stale italian bread',
#  'small fresh tomato',
#  'fresh spinach leaf',
#  'package penne pasta',
#  'vegetable broth',
#  'dry split pea',
#  'whole carrot optional',
#  'soy sauce',
#  'green sugar crystal',
#  'chop salt peanut',
#  'cherry grape tomato',
#  'pineapple apple juice',
#  'sweet pickle relish',
#  'fresh raspberry garnish',
#  'ground red pepper',
#  'green olive',
#  'style hot sauce',
#  'green food coloring',
#  'green chili pepper',
#  'lime juice such',
#  'citrus soda',
#  'clove garlic optional',
#  'steak seasoning rub',
#  'garbanzo bean flour',
#  'baby portabella mushroom',
#  'slice roast beef',
#  'fresh oregano',
#  'package tater tot',
#  'head fresh broccoli',
#  'hot sauce optional',
#  'fresh ground cumin',
#  'dry ancho chile',
#  'rotelle pasta',
#  'real bacon bit',
#  'fresh frozen blueberry',
#  'dash vanilla extract',
#  'ground pork',
#  'teriyaki sauce',
#  'lime vodka',
#  'ground allspice',
#  'light olive oil',
#  'slice american cheese',
#  'large acorn squash',
#  'butternut squash- peel',
#  'bag chocolate chip',
#  'slice pickle jalapeno',
#  'pinch ground clove',
#  'box elbow macaroni',
#  'seashell pasta',
#  'slice green onion',
#  'container plain yogurt',
#  'whole wheat bread',
#  'shred jarlsberg cheese',
#  'dry white wine',
#  'large mango peel',
#  'cubed butternut squash',
#  'bacon bit',
#  'small apple peel',
#  'slice cut bacon',
#  'package dry cranberry',
#  'flake coconut optional',
#  'apple slice garnish',
#  'sweet corn',
#  'canola oil',
#  'whole wheat couscous',
#  'slice deli ham',
#  'white miso',
#  'tart apple peel',
#  'slice pancetta bacon',
#  'grill chicken',
#  'instant tea powder',
#  'package fettuccine pasta',
#  'prepared coleslaw optional',
#  'caesar salad dressing',
#  'boneless beef chuck',
#  'head iceberg lettuce',
#  'tomato pasta sauce',
#  'sweet red wine',
#  'dry roasted peanut',
#  'dash angostura bitter',
#  'package rigatoni pasta',
#  'ground mustard seed',
#  'brine olive jar',
#  'slice vegetarian pepperoni',
#  'color food coloring',
#  'large roma tomato',
#  'coconut oil optional',
#  'package chocolate frosting',
#  'cooking roll oats',
#  'seed poblano chile',
#  'chile sauce garlic',
#  'crumble gorgonzola cheese',
#  'green maraschino cherry',
#  'slice cook bacon',
#  'baked pie shell',
#  'package cheese fill',
#  'pint fresh raspberry',
#  'dry mustard',
#  'plastic insect optional',
#  'pit green olive',
#  'crumble blue cheese',
#  'slice mozzarella cheese',
#  'feta cheese optional',
#  'bag broccoli floret',
#  'plain greek yogurt',
#  'bunch fresh cilantro',
#  'slice almond optional',
#  'red maraschino cherry',
#  'heavy cream optional',
#  'tear fresh spinach',
#  'whip cream',
#  'gorgonzola blue cheese',
#  'package pizza dough',
#  'dash ground cumin',
#  'poppy seed optional',
#  'rye whiskey',
#  'leftover roast turkey',
#  'fat sour cream',
#  'dry fettuccine pasta',
#  'package hormel pepperoni',
#  'flake coconut',
#  'medium red onion',
#  'cheddar cheese',
#  'bottle hot sauce',
#  'container pizza dough',
#  'jar peanut sauce',
#  'large turkey wing',
#  'liquid smoke flavor',
#  'cubed cook chicken',
#  'italian 3-cheese blend',
#  'package frozen strawberry',
#  'cubed brie cheese',
#  'pickle pepper juice',
#  'dice fresh tomato',
#  'jar pesto sauce',
#  'slice white bread',
#  'grated cheddar cheese',
#  'cider vinegar',
#  'flat leaf parsley',
#  'toffee baking bit',
#  'package queso fresco',
#  'spaghetti sauce',
#  'frozen diced carrot',
#  'powdered jalapeno pepper',
#  'jar yellow mustard',
#  'vanilla extract',
#  'package mozzarella cheese',
#  'container feta cheese',
#  'head napa cabbage',
#  'cashew piece',
#  'lump crab meat',
#  'boneless pork rib',
#  'triple sec',
#  'dry mustard powder',
#  'baking soda',
#  'white cheddar cheese',
#  'fresh chop broccoli',
#  'pinch dry parsley',
#  'mustard powder',
#  'agave nectar',
#  'ground beef',
#  'lowfat cream cheese',
#  'strong brew coffee',
#  'kielbasa sausage',
#  'peel sweet potato',
#  'coconut water',
#  'italian sausage link',
#  'vanilla soy milk',
#  ...}

# %%
outputs[4]
# Out:
# {'applewood smoke bacon',
#  'low sodium chicken broth',
#  'head iceberg lettuce rinse',
#  'light unsweetened soy milk',
#  'shred mexican blend cheese',
#  'bottle cold ginger ale',
#  'smoke sausage -PRON- choice',
#  'package white chocolate chip',
#  'black eyed pea',
#  'prosecco italian sparkle wine',
#  'hot chinese mustard optional',
#  'jigger strawberry vodka',
#  'cream onion soup',
#  'fluid pineapple juice',
#  'fresh hot chile pepper',
#  'ditalini pasta optional',
#  'whole berry cranberry sauce',
#  'beef consomme such',
#  'fresh mozzarella cheese',
#  'hickory flavor barbeque sauce',
#  'pineapple orange juice blend',
#  'container chicken stock',
#  'rum cream liqueur',
#  'beer such guinness',
#  'ranch style salad dressing',
#  'slice day old bread',
#  'package angel hair pasta',
#  'bag fresh broccoli floret',
#  'extra lean ground turkey',
#  'sodium chicken vegetable broth',
#  'package taco seasoning',
#  'jigger melon liqueur',
#  'bunch chop fresh cilantro',
#  'fluid grenadine syrup',
#  'sun dry tomato',
#  'season dry bread crumb',
#  'jar spaghetti sauce',
#  'colored candy coating melt',
#  'solid pack pumpkin',
#  'vanilla flavor confectioner coating',
#  'slice oscar center bacon',
#  'fresh jalapeno pepper seed',
#  'strong brew black tea',
#  'mince fresh rosemary',
#  'beef tri tip steak',
#  'package sliver almond',
#  'link bulk italian sausage',
#  'unsalt crunchy peanut butter',
#  'large vidalia sweet onion',
#  'thin slice deli ham',
#  'slice red bell pepper',
#  'deluxe canadian whiskey',
#  'frozen cook shrimp tail',
#  'pinch cayenne pepper optional',
#  'package fusilli spiral pasta',
#  'ground italian sausage',
#  'bean spicy sauce',
#  'slice cook deli ham',
#  'golden mushroom soup',
#  'piece lavash other flatbread',
#  'soft white hamburger bun',
#  'shred sharp cheddar cheese',
#  'dry split pea',
#  'cheddar cheese soup',
#  'dash dash worcestershire sauce',
#  'shred yellow summer squash',
#  'dice green bell pepper',
#  'package frozen macaroni cheese',
#  'pinch crush dry rosemary',
#  'brew espresso strong coffee',
#  'fresh dill weed',
#  'chop salt peanut',
#  'argo baking powder',
#  'grate orange zest',
#  'white wheat hamburger bun',
#  'kosher salt ground pepper',
#  'sweet pickle relish',
#  'extra sharp cheddar cheese',
#  'orange peach mango juice',
#  'semi sweet chocolate chip',
#  'green bell pepper',
#  'drop red food coloring',
#  'sprinkle colored sugar decoration',
#  'package slice pepperoni sausage',
#  'mince red bell pepper',
#  'small red bell pepper',
#  'package uncooked linguine pasta',
#  'container fruit flavor yogurt',
#  'package uncooked elbow macaroni',
#  'chop fresh parsley garnish',
#  'package dry rotini pasta',
#  'passion fruit juice',
#  'unseasoned bread crumb',
#  'grated parmesan romano cheese',
#  'whole wheat pita bread',
#  'thick slice bacon',
#  'bottle barbeque sauce',
#  'package chop romaine lettuce',
#  'grate parmigiano reggiano cheese',
#  'dry bread stuffing mix',
#  'grated asiago parmesan cheese',
#  'green food coloring',
#  'chill lemon lime soda',
#  'sharp white cheddar cheese',
#  'low fat vanilla yogurt',
#  'dash style hot sauce',
#  'sugar snap pea optional',
#  'borden vitamin milk',
#  'square semi sweet chocolate',
#  'chop fresh basil',
#  'confectioner sugar rolling',
#  'vanilla flavor candy coating',
#  'package milk chocolate chip',
#  'orange flesh sweet potato',
#  'vegetable bouillon such knorr',
#  'package seasoned goat cheese',
#  'fresh italian plum tomato',
#  'deep dish pie crust',
#  'italian flat leaf parsley',
#  'lettuce leaf rinse dry',
#  'small shell pasta macaroni',
#  'spicy italian sausage',
#  'multicolored candy sprinkle optional',
#  'slice slice cook ham',
#  'fluid half half',
#  'golden delicious apple peel',
#  'herb season stuffing mix',
#  'package cold cream cheese',
#  'dice silken tofu',
#  'small curd cottage cheese',
#  'package frozen potato round',
#  'grill chicken breast half',
#  'chocolate sandwich cookie crumb',
#  'whole green chile pepper',
#  'whole wheat elbow macaroni',
#  'package firm silken tofu',
#  'coarse grain brown mustard',
#  'pint heavy whipping cream',
#  'package ranch dressing mix',
#  'flax seed meal optional',
#  'large granny smith apple',
#  'package tortilla chip',
#  'bottle tomato juice',
#  'short stalk celery leaf',
#  'package frozen puff pastry',
#  'cook salad shrimp',
#  'fresh lemon juice',
#  'flax seed meal',
#  'peel cubed butternut squash',
#  'package farfalle tie pasta',
#  'dice black olive',
#  'fat smooth peanut butter',
#  'cranberry juice cocktail',
#  'package uncooked farfalle pasta',
#  'small head iceberg lettuce',
#  'package mozzarella cheese stick',
#  'bone beef pot roast',
#  'peppermint candy cane optional',
#  'shred italian cheese blend',
#  'grated fresh ginger root',
#  'jigger chocolate liqueur',
#  'slice green onion',
#  'italian seasoned breadcrumb',
#  'shred meat rotisserie chicken',
#  'mix berry fruit juice',
#  'dry roasted peanut optional',
#  'thin slice cook ham',
#  'peel cubed potato',
#  'package fresh button mushroom',
#  'apricot mango nectar',
#  'adobo sauce chipotle pepper',
#  'assorted vegetable broccoli',
#  'package freeze whip topping',
#  'vanilla fat free yogurt',
#  'bottle mango flavor rum',
#  'fluid orange liqueur',
#  'louisiana style hot sauce',
#  'reduce fat sour cream',
#  'package refrigerated biscuit dough',
#  'grate white cheddar cheese',
#  'loaf fresh italian bread',
#  'cubed cheddar mozzarella cheese',
#  'dash bitter such angostura',
#  'pinch white sugar optional',
#  'crush peppermint hard candy',
#  'pint slice fresh strawberry',
#  'hickory flavor liquid smoke',
#  'andouille smoke sausage',
#  'package butterscotch pudding mix',
#  'ground lean beef',
#  'jigger cherry vodka',
#  'package frozen english pea',
#  'package small shell pasta',
#  'fresh parsley optional',
#  'italian style stewed tomato',
#  'chipotle chilie adobo sauce',
#  'ground dry chipotle pepper',
#  'package cocktail rye bread',
#  'irish stout beer',
#  'dry italian herb',
#  'old fashioned roll oats',
#  'jar slice green olive',
#  'beef sirloin tip steak',
#  'sweet italian sausage',
#  'nonfat dry milk powder',
#  'sherry vinegar optional',
#  'bow tie penne pasta',
#  'slice dill pickle slice',
#  'bottle catalina salad dressing',
#  'package herb garlic feta',
#  'roasted red bell pepper',
#  'dijon mustard such hellmann',
#  'large curd cottage cheese',
#  'soft bread crumb',
#  'box barilla pronto rotini',
#  'package macaroni cheese',
#  'fresh lime juice',
#  'miniature semisweet chocolate chip',
#  'package chocolate graham cracker',
#  'package pretzel rod',
#  'pinch crush coriander seed',
#  'boneless beef chuck',
#  'link pork sausage link',
#  'room temperature beer',
#  'gluten free elbow pasta',
#  'sift confectioner sugar',
#  'crunchy peanut butter optional',
#  'college inn chicken broth',
#  'dijon style mustard',
#  'slice black olive',
#  'package uncooked rotini pasta',
#  'jigger dry gin',
#  'package uncooked orzo pasta',
#  'barbeque sauce such masterpiece',
#  'fresh orange juice',
#  'pimento stuff green olive',
#  'package wonton wrapper',
#  'spice pumpkin pie spice',
#  'jigger raspberry liqueur',
#  'jar mango slice',
#  'sift purpose flour',
#  'package corn bread mix',
#  'jigger canadian whiskey',
#  'green red bell pepper',
#  'package shred coleslaw mix',
#  'mayonnaise such good food',
#  'fluid spice rum',
#  'jigger citron vodka',
#  'granny smith apple peel',
#  'mince fresh ginger root',
#  'active dry yeast',
#  'italian prune plum',
#  'tomato garlic olive oil',
#  'container lite frozen whip',
#  'shred hash brown potato',
#  'russian style salad dressing',
#  'square german sweet chocolate',
#  'brine olive jar',
#  'crush butter flavor cracker',
#  'vegetable juice cocktail',
#  'chop dry mixed fruit',
#  'fresh shiitake mushroom',
#  'white vinegar optional',
#  'package mild cheddar cheese',
#  'square semisweet baking chocolate',
#  'italian style seasoning',
#  'slice deli roast beef',
#  'pinch salt black pepper',
#  'bag tortilla chip',
#  'jigger chocolate vodka',
#  'ground flax seed optional',
#  'jar roast red pepper',
#  'boneless beef chuck roast',
#  'loaf frozen bread dough',
#  'fresh red chile pepper',
#  'fresh red grapefruit juice',
#  'salt add tomato',
#  'package ready pizza crust',
#  'whole wheat flour tortilla',
#  'blue cheese dress',
#  'jar peanut butter',
#  'meat such spam',
#  'package baby spinach leaf',
#  'ground red chile pepper',
#  'blue curacao liqueur',
#  'old bay seasoning',
#  'fresh frozen broccoli floweret',
#  'package dry navy bean',
#  'package shred cheese blend',
#  'package buttery round cracker',
#  'pit green olive',
#  'lemonade such minute maid',
#  'sift pastry flour',
#  'gluten free bread slice',
#  'slice mozzarella cheese',
#  'process cheese such velveeta',
#  'thick slice cook ham',
#  'chop peanut optional',
#  'dry italian herb seasoning',
#  'dry mince garlic optional',
#  'loaf cocktail rye bread',
#  'feta cheese optional',
#  'fresh chevre goat cheese',
#  'sprig fresh thyme leaf',
#  'piece fresh ginger root',
#  'fluid lime juice',
#  'cream broccoli soup',
#  'package maple flavor sausage',
#  'cornichon small dill pickle',
#  'low moisture mozzarella cheese',
#  'italian tomato sauce',
#  'slice green olive',
#  'philadelphia cream cheese',
#  'caramel ice cream top',
#  'package bake pizza crust',
#  'loaf french bread',
#  'fluid cranberry juice',
#  'packet dry fajita seasoning',
#  'gold petite diced onion',
#  'package spinach fettuccine pasta',
#  'container low fat yogurt',
#  'boneless skinless chicken breast',
#  'concord grape juice',
#  'fresh poblano chile pepper',
#  'sliced vine ripe tomato',
#  'package process cheese food',
#  'coffee flavor liqueur',
#  'chocolate candy such hershey',
#  'fat free soy milk',
#  'jar spaghetti sauce meat',
#  'fluid amaretto liqueur',
#  'dry rainbow radiatore pasta',
#  'artichoke heart water',
#  'package firm tofu',
#  'pizza crust dough',
#  'fresh basil leaf',
#  'bottle ranch dressing optional',
#  'package shred cheddar cheese',
#  'fluid chocolate liqueur',
#  'chipotle chile adobo sauce',
#  'flavor fruit jelly',
#  'container strawberry banana yogurt',
#  'ground anise seed optional',
#  'cinnamon red hot candy',
#  'colby monterey jack cheese',
#  'crush plain tortilla chip',
#  'caraway seed optional',
#  'soft goat cheese',
#  'package prepared pizza dough',
#  'hickory flavor barbecue sauce',
#  'slice yellow red onion',
#  'crushed peppermint hard candy',
#  'package fresh baby spinach',
#  'pork sausage link',
#  'large pitted black olive',
#  'coarse ground black pepper',
#  'process cheese food',
#  'creamy caesar salad dressing',
#  'package pizza crust dough',
#  'medium sweet apple peel',
#  'toast sesame seed',
#  'package mixed vegetable cauliflower',
#  'warm water c',
#  'peanut oil fry',
#  'package small twisted pasta',
#  'hot chile paste optional',
#  'slice white american cheese',
#  'package medium seashell pasta',
#  'liquid smoke flavor',
#  'white sugar decoration',
#  'white cranberry juice',
#  'italian style salad dressing',
#  'oil cure olive',
#  'square egg roll wrapper',
#  'package cream cheese chive',
#  'mince fresh parsley',
#  'fluid apple cider',
#  'package grated parmesan cheese',
#  'small fresh jalapeno pepper',
#  'smooth peanut butter',
#  'burrito size flour tortilla',
#  'bake pizza crust',
#  'box barilla gluten free',
#  'loaf process cheese food',
#  'low fat plain yogurt',
#  'pit black olive optional',
#  'pinch dry dill weed',
#  'package cook ham steak',
#  'bottle caesar salad dressing',
#  'quick cooking oats',
#  'panko bread crumb',
#  'cherry vanilla carbonate cola',
#  'package unflavored gelatin',
#  'container nonfat sour cream',
#  'slice american process cheese',
#  'orange flavor liqueur',
#  'slice seedless rye bread',
#  'instant coffee granule',
#  'fluid butterscotch schnapps',
#  'dice red bell pepper',
#  'new england chowder',
#  'whole wheat pastry flour',
#  'dehydrated sun dry tomato',
#  'cook bay shrimp',
#  'prepared pizza dough',
#  'container light sour cream',
#  'cream cheese chive',
#  'instant coffee optional',
#  'flax seed oil',
#  'large portobello mushroom cap',
#  'long strip lemon zest',
#  'slice stuff green olive',
#  'red wine optional',
#  'package brownie mix',
#  'package ramen noodle pasta',
#  'slice slice deli turkey',
#  'bunch chop green onion',
#  'uncooked long grain rice',
#  'freeze mixed berry',
#  'milk chocolate candy bar',
#  'dry small elbow macaroni',
#  'package wide egg noodle',
#  'chop pimento pepper optional',
#  'fluid silver tequila',
#  'pint fresh blueberry rinse',
#  'pack dry apricot',
#  'bottle italian salad dressing',
#  'jar slice pimento pepper',
#  'fluid orange juice',
#  'fat free refried bean',
#  'pop butter flavor popcorn',
#  'small green bell pepper',
#  'package small pasta shell',
#  'season bread crumb',
#  'head leaf lettuce rinse',
#  'jar pasta sauce',
#  'jigger vanilla vodka',
#  'diced red bell pepper',
#  'frozen italian style meatball',
#  'bag baby spinach leaf',
#  'virgin olive oil',
#  'peel deveined medium shrimp',
#  'fluid white rum',
#  'shred smoke gouda cheese',
#  'sprig fresh dill weed',
#  'slice monterey jack cheese',
#  'whole wheat penne pasta',
#  'dry mustard powder',
#  'fluid lemon juice',
#  'package vanilla bake chip',
#  'pinch ground black pepper',
#  'container whip ricotta cheese',
#  'pack brown sugar',
#  'medium shrimp peel deveined',
#  'package frozen chop broccoli',
#  'fresh flat leaf parsley',
#  'slice dark rye bread',
#  'fluid sweet vermouth',
#  'shred mexican style cheese',
#  'chop fresh dill',
#  'square spring roll wrapper',
#  'bag frozen mixed vegetable',
#  'green food coloring optional',
#  'pinch ground cayenne pepper',
#  'packet taco seasoning mix',
#  'yellow mustard optional',
#  'envelope onion soup mix',
#  'toast coconut vanilla yogurt',
#  'package whip cream cheese',
#  'hot pepper sauce optional',
#  'sift cake flour',
#  'ground star anise',
#  'rib eye steak',
#  'package slice baby mushroom',
#  'slice shred mozzarella cheese',
#  'whole wheat bread crumb',
#  'bunch slender asparagus spear',
#  'prepared basil pesto sauce',
#  'graham cracker pie crust',
#  'package bow tie pasta',
#  'raw whole pumpkin seed',
#  'fat free plain yogurt',
#  'bottle proof bourbon whiskey',
#  '16-inch pizza dough pastry',
#  'cream style corn',
#  'lemon lime soda',
#  'process american cheese',
#  'jar stuff green olive',
#  'package frozen tater tot',
#  'flat leaf parsley leaf',
#  'package buttermilk biscuit dough',
#  'low fat sour cream',
#  'package refrigerated crescent roll',
#  'whole kernel corn',
#  'milk chocolate chip optional',
#  'package chow noodle',
#  'italian seasoning blend',
#  'creamy salad dressing',
#  'white creme cacao',
#  'hot sauce such tabasco',
#  'package taco seasoning mix',
#  'dice chicken breast meat',
#  'diced fresh jalapeno pepper',
#  'kikkoman pearl original soymilk',
#  'jar vodka marinara sauce',
#  'package frozen egg noodle',
#  'package broccoli coleslaw mix',
#  'italian style plum tomato',
#  'cook lobster tail',
#  'pumpkin pie spice',
#  'grind black pepper',
#  'food coloring optional',
#  'refrigerated pizza crust',
#  'chicken breast tenderloin strip',
#  'jalapeno stuff green olive',
#  'taco seasoning mix',
#  'small fresh mozzarella ball',
#  'container style pasta sauce',
#  'container blueberry nonfat yogurt',
#  'shred white cheddar cheese',
#  'oil sun dry tomato',
#  'lean ground lamb',
#  'pinch ground cinnamon optional',
#  'dice firm tofu',
#  'bone chicken breast half',
#  'sweet sour mix',
#  'triple sec liqueur',
#  'mild cheddar cheese',
#  'dry dill weed',
#  'bread machine yeast',
#  'fluid creme liqueur',
#  'package mini potato gnocchi',
#  'low salt worcestershire sauce',
#  'bone pork shoulder roast',
#  'sprig fresh mint leaf',
#  'firm ripe bartlett pear',
#  'classic pizza dough',
#  'package dry penne pasta',
#  'ground pork breakfast sausage',
#  'envelope microwave popcorn butter',
#  'pinch ground nutmeg optional',
#  'whole wheat rotini pasta',
#  'french style green bean',
#  'sour apple schnapps',
#  'package italian 6-cheese blend',
#  'jigger creme cacao',
#  'cream mushroom soup',
#  'red enchilada sauce',
#  'head romaine lettuce rinse',
#  'strawberry flavor jell o',
#  'unbaked 9-inch pie crust',
#  'yukon gold potato',
#  'pickled jalapeno pepper slice',
#  'fresh cilantro leaf',
#  'fluid irish whiskey',
#  'package powdered fruit pectin',
#  'unsalted butter room temperature',
#  'thick slice french bread',
#  'boneless chicken breast half',
#  'warm water f',
#  'scoop vanilla protein powder',
#  'shred smoke cheddar cheese',
#  'scoop vanilla ice cream',
#  'fresh cauliflower floret',
#  'envelope taco seasoning mix',
#  'fresh thyme leaf',
#  'slice peel cucumber',
#  'cream celery soup',
#  'crush vanilla wafer',
#  'jigger orange juice',
#  'ground white black pepper',
#  'frozen lemonade concentrate',
#  'dice green onion',
#  'broccoli floret optional',
#  'chop roasted almond',
#  'shred cheddar cheese',
#  'baking powder optional',
#  'large anaheim chile pepper',
#  'grated parmesan cheese optional',
#  'bag corn chip',
#  'bulk mild italian sausage',
#  'shortening vegetable oil optional',
#  'frozen limeade concentrate',
#  'vegetarian hot dog',
#  'red kidney bean',
#  'container cream cheese frost',
#  'package powdered pectin',
#  'chicken gumbo soup',
#  'package color rotini pasta',
#  'creamy peanut butter optional',
#  'slice pepperoni sausage',
#  'package dry ziti pasta',
#  'package refrigerated fresh cheese',
#  'jigger tennessee whiskey',
#  'count hawaiian bread roll',
#  'ground beef grass feed',
#  'vegetable oil fry',
#  'candy coat chocolate piece',
#  'fat free half',
#  'old bay seasoning tm',
#  'process cheese sauce',
#  'cubed beef stew meat',
#  'grate pecorino romano cheese',
#  'slice diced provolone cheese',
#  'small yellow bell pepper',
#  'tonkatsu sauce barbeque sauce',
#  'olive oil canola oil',
#  'loaf italian bread',
#  'self rise flour',
#  'container coconut pecan frosting',
#  'irish cream liqueur',
#  'dice jalapeno pepper',
#  'jar real bacon bit',
#  'chop cook ham',
#  'jigger spice rum',
#  'hawaiian sea salt',
#  'fluid coconut rum',
#  'chop fresh parsley',
#  'package shred american cheese',
#  'good quality vodka',
#  'package tri color pasta',
#  'head iceberg lettuce leaf',
#  'crush buttery round cracker',
#  'package peanut butter chip',
#  'package graham cracker square',
#  'boneless pork shoulder roast',
#  'balsamic vinaigrette salad dressing',
#  'fat free mozzarella cheese',
#  'instant mash potato flake',
#  'agave nectar optional',
#  'asian chili paste sambal',
#  'bottle barbecue sauce',
#  'package frozen mixed berry',
#  'cholesterol free egg product',
#  'package frozen cheese',
#  'vanilla flavor vodka',
#  'cold club soda',
#  'french fry onion ring',
#  'small frozen banana freeze',
#  'shred pizza cheese blend',
#  'season salt such',
#  'apple cider vinegar',
#  'bunch fresh spinach leaf',
#  'whole wheat bread flour',
#  'hot red pepper flake',
#  'whole grain english muffin',
#  'container light whip topping',
#  'fresh herb basil',
#  'large prepared pizza crust',
#  'hot buffalo wing sauce',
#  'hot chocolate mix such',
#  'jar tomato pasta sauce',
#  'chop chicken breast meat',
#  'package frozen broccoli floret',
#  'apple pie fill',
#  'chill club soda',
#  'toast sesame oil',
#  'package shred mozzarella cheese',
#  'dash red pepper flake',
#  'tomato base chili sauce',
#  'slice marble rye bread',
#  'slice green bell pepper',
#  'powder chocolate drink mix',
#  'package process american cheese',
#  'jigger cranberry juice',
#  'raw spanish peanut',
#  'grate fresh ginger root',
#  'fresh italian parsley',
#  'color sugar decoration',
#  'bison sausage pepperoni seasoning',
#  'package extra firm tofu',
#  'tomato clam juice cocktail',
#  'lemon lime flavor beverage',
#  'large red bell pepper',
#  'milk chocolate candy kiss',
#  'package dry rice noodle',
#  'fresh mint leaf',
#  'link spicy pork sausage',
#  '% pure pumpkin',
#  'chocolate cookie crumb crust',
#  'vegetable oil deep frying',
#  'shred mozzarella cheese',
#  'fluid peach schnapps',
#  'dark sesame oil',
#  'fluid cherry vodka',
#  'thai peanut sauce',
#  'shred cook corned beef',
#  'head red leaf lettuce',
#  'cold heavy cream',
#  'pint vanilla ice cream',
#  'slice cook turkey meat',
#  'montreal steak seasoning',
#  'package medium pasta shell',
#  'thin chicken breast cutlet',
#  'liquid smoke flavoring optional',
#  'great northern bean',
#  'dry red pepper flake',
#  'bottle zesty italian dressing',
#  'package dry egg noodle',
#  'square unsweetened baking chocolate',
#  'package semisweet chocolate chip',
#  'jigger raspberry vodka',
#  'turkey chili bean',
#  'slice low sodium bacon',
#  'creme fraiche sour cream',
#  'square wonton wrapper',
#  'dry italian seasoning',
#  'package uncooked penne pasta',
#  'cracker barrel shred cheese',
#  'coarse ground mustard',
#  'pack light brown sugar',
#  'container freeze whip topping',
#  'beef eye round roast',
#  'large head napa cabbage',
#  'package single ready make',
#  'black olive drain',
#  'instant coffee powder',
#  'package sharp cheddar cheese',
#  'green chile enchilada sauce',
#  'jigger amaretto liqueur',
#  'colby jack natural shred',
#  'package small seashell pasta',
#  'slab baby pork rib',
#  'lime slice cut half',
#  'crush red pepper flake',
#  'low fat cottage cheese',
#  'large shrimp peel deveined',
#  'cointreau triple sec',
#  'jigger grenadine syrup',
#  'slice fresh mozzarella cheese',
#  'package chocolate sandwich cookie',
#  'sweeten coconut cream',
#  'pork butt roast',
#  'jar dill pickle relish',
#  'heavy whipping cream',
#  'boneless lamb shoulder',
#  'dash hot pepper sauce',
#  'boneless pork loin chop',
#  'bite size broccoli floret',
#  'package frozen cut okra',
#  'crush corn flake cereal',
#  'beef stew meat',
#  'wish bone italian dressing',
#  'medium butternut squash peel',
#  'small sprig mint optional',
#  'shred heart romaine lettuce',
#  'bunch fresh cilantro garnish',
#  'dry bread crumb',
#  'vanilla flavor soy milk',
#  'fluid melon liqueur',
#  'slice sirloin steak strip',
#  'pastry 9-inch pie crust',
#  'thin slice cheddar cheese',
#  'red food coloring',
#  'peppermint candy cane',
#  'beef rib eye steak',
#  'slice red yellow onion',
#  'fat free half half',
#  'yellow food coloring optional',
#  'smoke gouda cheese',
#  'package frozen green pea',
#  'packet stevia powder optional',
#  'chocolate cover caramel candy',
#  'low fat milk',
#  'extra lean ground beef',
#  'chickpea garbanzo bean',
#  'baked thin pizza crust',
#  'confectioner sugar decoration',
#  'light brown sugar',
#  'fat free cottage cheese',
#  'basket cherry grape tomato',
#  'bow tie farfalle pasta',
#  'asian garlic chili sauce',
#  'deli slice corned beef',
#  'paula red apple peel',
#  'slice process american cheese',
#  'package cheddar cheese',
#  'ground pork sausage',
#  'unsweetened pineapple juice',
#  'chop green bell pepper',
#  'package instant stuffing mix',
#  'chocolate flavor protein powder',
#  'cub sharp cheddar cheese',
#  'fresh bread crumb',
#  'package refrigerated pizza crust',
#  'dry mexican oregano',
#  'shred cook chicken meat',
#  'garlic powder such',
#  'medium red bell pepper',
#  'fresh jalapeno chile pepper',
#  'package frozen chop spinach',
#  'package philadelphia cream cheese',
#  'red food coloring optional',
#  'small peppermint candy cane',
#  'grate orange peel',
#  'ranch style bean',
#  'jigger bourbon whiskey',
#  'bite size cauliflower floret',
#  'double concentrated tomato paste',
#  'turkey stock pan dripping',
#  'crispy rice cereal square',
#  'grate sharp cheddar cheese',
#  'shred monterey jack cheese',
#  'ground cayenne pepper optional',
#  'milk chocolate candy',
#  'italian style dice tomato',
#  'package pork gravy mix',
#  'hot pepper sauce',
#  'package monterey jack cheese',
#  'dry parsley flake',
#  'large green bell pepper',
#  'pastry double crust pie',
#  'cubed process cheese food',
#  'whole wheat macaroni',
#  'container nonfat plain yogurt',
#  'ground black pepper',
#  'unsweetened cocoa powder optional',
#  'chop macadamia nut',
#  'frozen orange juice concentrate',
#  'bar chocolate cover toffee',
#  'half half cream',
#  'jar pizza sauce',
#  'envelope fleischmann rapidrise yeast',
#  'tri color spiral pasta',
#  'freeze whip topping',
#  'mini chocolate chip',
#  'sleeve buttery round cracker',
#  'italian salad dressing',
#  'extra virgin olive oil',
#  'sprig chop fresh parsley',
#  'cold unsalted butter',
#  'medium green bell pepper',
#  'fluid peppermint schnapps',
#  'tube red gel',
#  'jigger vodka optional',
#  'creamy peanut butter',
#  'basil flavor feta cheese',
#  'package fat cream cheese',
#  'package vanilla sandwich cookie',
#  'slice deli turkey meat',
#  'fluid dry vermouth',
#  'jigger butterscotch schnapps',
#  'mince fresh ginger',
#  'dry white wine optional',
#  'tub spreadable goat cheese',
#  'cub skinless cook turkey',
#  'french italian sandwich roll',
#  'shred mexican cheese blend',
#  'mix salad green arugula',
#  'unsalted butter unsalted margarine',
#  'fluid blue curacao',
#  'chocolate mint wafer candy',
#  'fluid triple sec',
#  'fluid skim milk',
#  'cream tomato soup',
#  'package uncooked egg noodle',
#  'jar quarter heart water',
#  'package slice button mushroom',
#  'shred asiago mozzarella cheese',
#  'warm water degree',
#  'fluid pear vodka',
#  'dry mince garlic',
#  'chop toast hazelnut',
#  'black bean soup',
#  'kraft sharp cheddar cheese',
#  'package uncooked pasta shell',
#  'graham cracker crumb',
#  'round loaf sourdough bread',
#  'gold petite diced green',
#  'drop hot pepper sauce',
#  'red white wine vinegar',
#  'solid pack pumpkin puree',
#  'boneless pork loin roast',
#  'high quality white chocolate',
#  'recipe unbaked pie shell',
#  'chop cook pork',
#  'cubed chicken breast meat',
#  'unsweetened coconut cream',
#  'chop seed cucumber',
#  'grated parmesan cheese top',
#  'pinch ground white pepper',
#  'kidney bean liquid',
#  'package dry yeast',
#  'red pepper flake optional',
#  'store buy roast chicken',
#  'recipe creamy macaroni cheese',
#  'package dry pectin',
#  'green enchilada sauce',
#  'lychee juice can lychee',
#  'plain low fat yogurt',
#  'low fat % milk',
#  'grate vermont cheddar cheese',
#  'tomato green chile pepper',
#  'fresh ginger root',
#  'chop nut optional',
#  'unsweetened natural peanut butter',
#  'pinch coarse sea salt',
#  'cream style horseradish sauce',
#  'link chicken cheese sausage',
#  'sprig fresh parsley garnish',
#  'chop sun dry tomato',
#  'fat process cheese food',
#  'slice multigrain bread crust',
#  'chop chicken breast',
#  'bar chocolate candy bar',
#  'package uncooked shell pasta',
#  'tear fresh basil leaf',
#  'individual package graham cracker',
#  'uncooked instant white rice',
#  'white sugar decoration optional',
#  'ground beef % lean',
#  'concentrated beef base paste',
#  'dry basil leaf',
#  'bar chocolate english toffee',
#  'chop dill pickle optional',
#  'package cavatappi corkscrew macaroni',
#  'blue cheese salad dressing',
#  'shred colby cheese',
#  'package instant yeast',
#  'whole fresh spinach leaf',
#  'dice poblano pepper',
#  'teriyaki basting sauce',
#  'green decorator sugar optional',
#  'cream potato soup',
#  'dice red onion',
#  'frozen chop spinach thaw',
#  'vegetarian refried bean',
#  'slice provolone cheese',
#  'barilla garlic sauce',
#  'fresh slice mushroom',
#  'rotini corkscrew pasta',
#  'loaf crusty french bread',
#  'white rum such',
#  'ground breakfast sausage',
#  'beer such budweiser',
#  'jar meatless spaghetti sauce',
#  'frozen hash brown potato',
#  'bottle bottled coleslaw dress',
#  'ground white pepper optional',
#  'instant hot chocolate mix',
#  'whole wheat pizza crust',
#  'oil cure black olive',
#  'confectioner sugar dusting',
#  'sharp cheddar cheese',
#  'boneless skinless chicken thigh',
#  'italian seasoning optional',
#  '% fat milk',
#  'container pizza dough such',
#  'grape flavor sport drink',
#  'shred mild cheddar cheese',
#  'small frozen chicken tender',
#  'large fresh jalapeno pepper',
#  'chop pickle hot pepper',
#  'slice canadian style bacon',
#  'dry great northern bean',
#  'jigger pineapple juice',
#  'kraft cheddar cheese',
#  'part skim ricotta cheese',
#  'reduce fat mayonnaise optional',
#  'jigger blue curacao',
#  'mexican vanilla extract',
#  'white wine vinegar',
#  'package cream cheese',
#  'sprig fresh dill garnish',
#  'frozen cook chicken strip',
#  'package dry elbow macaroni',
#  'chinese 5-spice powder',
#  'beef bouillon granule',
#  'barilla tomato basil sauce',
#  'slice soft white bread',
#  'cream chicken soup',
#  'fluid creme cacao',
#  'package sister dinner yeast',
#  'container fat sour cream',
#  'unsweetened cocoa powder',
#  'box chicken flavor cracker',
#  'cayenne pepper hot sauce',
#  'slice capacola sausage',
#  'box frozen chop spinach',
#  'keystone light beer',
#  'sun dry tomato pesto',
#  'instant iced tea powder',
#  'package rotini corkscrew pasta',
#  'key lime juice',
#  'high quality semisweet chocolate',
#  'jar marinara sauce',
#  'chicken broth chicken',
#  'fluid ginger ale',
#  'package light cream cheese',
#  'pepper jack cheese',
#  'package little smokie sausage',
#  'rum flavor extract',
#  'shred colby jack cheese',
#  'french onion soup',
#  'red rice wine vinegar',
#  'dark brown sugar',
#  'thick boneless pork chop',
#  'dash ground black pepper',
#  'container liquid pectin',
#  'medium sweet gherkin pickle',
#  ...}

# %%
outputs[5]
# Out:
# {'agave nectar simple syrup',
#  'american process cheese single',
#  'asian dark sesame oil',
#  'bag chop dry mixed fruit',
#  'bag corn chip such',
#  'bag frozen chop broccoli',
#  'bag frozen mexican style corn',
#  'bag milk chocolate candy kiss',
#  'bag potato chip such lay',
#  'bag semi sweet chocolate chip',
#  'bag shred mexican cheese blend',
#  'ball park hot dog bun',
#  'bar chocolate flavor confectioner coat',
#  'bar milk chocolate crispy rice',
#  'black bean reserve liquid',
#  'black eyed pea liquid',
#  'blue cheese salad dressing',
#  'boneless beef chuck roast',
#  'boneless pork loin roast',
#  'boneless skinless chicken breast',
#  'boneless skinless chicken breast half',
#  'boston bibb butter lettuce leaf',
#  'bottle blue cheese salad dressing',
#  'bottle favorite barbecue sauce',
#  'bottle hickory smoke barbeque sauce',
#  'bottle hot red pepper sauce',
#  'bottle italian style salad dressing',
#  'bottle lemon lime flavor beverage',
#  'bottle prosecco italian sparkle wine',
#  'bottle ranch style salad dressing',
#  'bottle salad seasoning mix',
#  'bottle tomato base chili sauce',
#  'box yellow cake mix',
#  'bulk pork sausage optional',
#  'bunch flat leaf italian parsley',
#  'candy coat milk chocolate piece',
#  'center cut bone pork chop',
#  'cheddar cheese soup such',
#  'chile garlic sauce such sriracha',
#  'chipotle pepper chipotle adobo sauce',
#  'chocolate cover peanut butter',
#  'chocolate creme fill sandwich cookie',
#  'chocolate hazelnut spread such nutella',
#  'chocolate sandwich cookie creme fill',
#  'chop giardiniera pickle italian vegetable',
#  'chop pimento stuff green olive',
#  'chop sun dry tomato',
#  'chunk drain juice reserve',
#  'cointreau other orange liqueur',
#  'cola flavor carbonate beverage',
#  'container barbeque pull pork',
#  'container chive onion cream cheese',
#  'container fat free cream cheese',
#  'container fruit flavor cream cheese',
#  'container low fat cottage cheese',
#  'container low fat ricotta cheese',
#  'container plain greek style yogurt',
#  'container small curd cottage cheese',
#  'container vanilla fat free yogurt',
#  'container vanilla low fat yogurt',
#  'cook chicken breast strip',
#  'cook lobster tail meat',
#  'cook shrimp peel deveined',
#  'corned beef brisket spice packet',
#  'country style pork rib',
#  'cream chicken mushroom soup',
#  'cream chicken soup herb',
#  'cream chicken soup regular',
#  'cream mushroom soup regular',
#  'creamy poblano queso soup',
#  'creamy salad dressing miracle whip',
#  'crumble feta cheese basil tomato',
#  'crush buttery round cracker crumb',
#  'crush red pepper flake',
#  'cub fresh mozzarella cheese',
#  'cub pasteurize prepared cheese product',
#  'dash asian chile pepper sauce',
#  'dash hot pepper sauce tabasco',
#  'dash hot sauce such tabasco',
#  'dash red green food coloring',
#  'deli slice corn beef',
#  'dice green bell pepper',
#  'dice orange bell pepper',
#  'dice red bell pepper',
#  'digiorno grated romano cheese',
#  'dry farfalle tie pasta',
#  'dry italian herb blend',
#  'dry italian herb seasoning',
#  'dry pizza crust mix',
#  'dry ranch salad dressing mix',
#  'dry red pepper flake optional',
#  'durkee fine grind black pepper',
#  'dutch process cocoa powder',
#  'earl grey tea leave',
#  'envelope active dry yeast',
#  'envelope dry onion soup mix',
#  'envelope fleischmann pizza crust yeast',
#  'envelope hollandaise sauce mix',
#  'envelope instant hot chocolate mix',
#  'extra crunchy peanut butter',
#  'extra lean ground beef',
#  'extra lean ground turkey breast',
#  'extra sharp cheddar cheese',
#  'extra sharp white cheddar cheese',
#  'extra virgin olive oil',
#  'extra virgin olive oil optional',
#  'fast rise dry yeast',
#  'fat cream chicken soup',
#  'fat free italian style dressing',
#  'flax seed meal wheat germ',
#  'fluid coffee flavor liqueur',
#  'fluid cointreau triple sec',
#  'fluid cola flavor beverage',
#  'fluid frozen limeade concentrate',
#  'fluid irish cream liqueur',
#  'fluid lemon flavor vodka',
#  'fluid strawberry flavor syrup',
#  'fluid vanilla flavor vodka',
#  'fluid warm water c',
#  'fluid white chocolate liqueur',
#  'fluid white creme cacao',
#  'fresh bean sprout optional',
#  'fresh flat leaf parsley',
#  'fresh lemon juice optional',
#  'fresh thick chinese wheat noodle',
#  'frozen orange juice concentrate',
#  'frozen shred hash brown potato',
#  'gluten free purpose flour',
#  'grand homestyle original biscuit',
#  'granny smith apple peel',
#  'granular sucrolose sweetener such splenda',
#  'grate fresh parmesan cheese optional',
#  'grate sharp white cheddar cheese',
#  'grated extra sharp cheddar cheese',
#  'green bell pepper optional',
#  'green pepper frozen pea',
#  'ground dry chipotle pepper',
#  'ground red chile pepper',
#  'half half vanilla ice cream',
#  'halloween color chocolate sandwich cookie',
#  'hawaiian bread roll split toast',
#  'hickory smoke flavor barbeque sauce',
#  'hot cook medium egg noodle',
#  'hot italian pork sausage',
#  'hot italian turkey sausage',
#  'hot pepper sauce such tabasco',
#  'hot pepper sauce tabasco',
#  'hot sauce such frank redhot',
#  'hot sauce such red hot',
#  'hot smoke sausage link',
#  'instant mash potato flake',
#  'italian flat leaf parsley',
#  'italian sausage link optional',
#  'italian season bread crumb',
#  'italian seasoned bread crumb',
#  'italian style bread crumb',
#  'italian style salad dressing',
#  'italian style season bread crumb',
#  'jar alfredo style pasta sauce',
#  'jar caramel ice cream top',
#  'jar pimento stuff green olive',
#  'jar roast red bell pepper',
#  'jar sausage flavor spaghetti sauce',
#  'jif creamy fat peanut spread',
#  'jif creamy peanut butter',
#  'jigger bottle lime juice',
#  'jigger cake flavor vodka',
#  'jigger coconut flavor rum',
#  'jigger coffee flavor liqueur',
#  'jigger irish cream liqueur',
#  'jigger lemon flavor rum',
#  'jigger orange liqueur cointreau',
#  'jigger rum dark light',
#  'jigger vanilla flavor vodka',
#  'large boneless skinless chicken breast',
#  'large granny smith apple peel',
#  'large red leaf lettuce leaf',
#  'large shrimp peel deveined',
#  'large vidalia other sweet onion',
#  'light corn syrup such karo',
#  'light ranch style salad dressing',
#  'loaf french italian style bread',
#  'loaf frozen white bread dough',
#  'low fat vanilla soy milk',
#  'low sodium chicken broth',
#  'low sodium tomato soup',
#  'low sodium vegetable juice',
#  'medium granny smith apple peel',
#  'mexican style shred cheese blend',
#  'mince chipotle pepper adobo sauce',
#  'mince fresh ginger root',
#  'mince italian flat leaf parsley',
#  'mini candy coat chocolate',
#  'mini semi sweet chocolate chip',
#  'mirin japanese sweet rice wine',
#  'mocha flavor instant coffee mix',
#  'multi color fusilli pasta',
#  'new mexico california chili powder',
#  'new mexico chile powder',
#  'ocean spray blueberry juice cocktail',
#  'oil base peppermint flavoring',
#  'oil pack sun dry tomato',
#  'old bay seasoning tm',
#  'orange curacao orange flavor liqueur',
#  'orange liqueur such grand marnier',
#  'orange mango juice blend',
#  'pack light brown sugar',
#  'package angel food cake mix',
#  'package bake pizza crust',
#  'package baked thin pizza crust',
#  'package beef cocktail wiener',
#  'package bow tie farfalle pasta',
#  'package bow tie pasta farfalle',
#  'package bread machine yeast',
#  'package butter cake mix',
#  'package butter flavor microwave popcorn',
#  'package buttermilk biscuit dough',
#  'package chicken flavor ramen noodle',
#  'package chicken flavor stuffing mix',
#  'package chili seasoning mix',
#  'package chili seasoning such',
#  'package chocolate cake mix',
#  'package chocolate cover thin mint',
#  'package corn bread mix',
#  'package corn tortilla chip',
#  'package country style gravy mix',
#  'package cream cheese room temperature',
#  'package crispy corn rice cereal',
#  'package dry alfredo sauce mix',
#  'package dry beef gravy mix',
#  'package dry bread stuffing mix',
#  'package dry corn bread mix',
#  'package dry enchilada sauce mix',
#  'package dry leek soup mix',
#  'package dry macaroni cheese',
#  'package dry onion soup mix',
#  'package dry pizza crust mix',
#  'package dry yeast',
#  'package extra sharp cheddar cheese',
#  'package fat free cream cheese',
#  'package frozen chop spinach thaw',
#  'package frozen hash brown potato',
#  'package frozen puff pastry',
#  'package frozen soy burger style',
#  'package hillshire farm smoke sausage',
#  'package hollandaise sauce mix',
#  'package instant banana pudding mix',
#  'package instant butterscotch pudding mix',
#  'package instant chocolate pudding mix',
#  'package instant lemon pudding mix',
#  'package instant mash potato flake',
#  'package instant pistachio pudding mix',
#  'package instant vanilla pudding mix',
#  'package kraft mozzarella cheese touch',
#  'package lemon cake mix',
#  'package macaroni cheese mix',
#  'package milk chocolate chip',
#  'package mini candy coat chocolate',
#  'package mini twist pretzel',
#  'package orange cake mix',
#  'package pace taco seasoning mix',
#  'package part skim mozzarella cheese',
#  'package pastry double crust pie',
#  'package pizza crust dough',
#  'package polish beef sausage',
#  'package process cheese such velveeta',
#  'package ranch salad dressing mix',
#  'package ranch style dressing mix',
#  'package rapid rise yeast',
#  'package ready chicken breast strip',
#  'package real bacon piece bit',
#  'package refrigerated crescent roll dough',
#  'package refrigerated pie crust',
#  'package refrigerated pizza crust',
#  'package refrigerated pizza crust dough',
#  'package refrigerated pizza dough',
#  'package seasoned cornbread stuffing mix',
#  'package semi sweet chocolate chip',
#  'package shred cheddar cheese optional',
#  'package shred italian cheese blend',
#  'package shred mild cheddar cheese',
#  'package shred monterey jack cheese',
#  'package shred pepper jack cheese',
#  'package shred pizza cheese blend',
#  'package shred sharp cheddar cheese',
#  'package small pretzel twist',
#  'package small uncooked seashell pasta',
#  'package spice cake mix',
#  'package strawberry flavor jell o',
#  'package taco seasoning mix',
#  'package thin rice noodle',
#  'package tomato basil feta cheese',
#  'package tri color pasta assortment',
#  'package tri color rotini pasta',
#  'package uncooked farfalle tie pasta',
#  'package uncooked macaroni cheese',
#  'package uncooked medium egg noodle',
#  'package white cake mix',
#  'package white chocolate baking square',
#  'package whole grain elbow macaroni',
#  'package whole wheat elbow macaroni',
#  'package yellow cake mix',
#  'packet dry onion soup mix',
#  'packet dry vegetable soup mix',
#  'parmesan cheese flavor bread crumb',
#  'pastry 10-inch double crust pie',
#  'pepper sauce such red hot',
#  'pesto homemade refrigerated prepared variety',
#  'piece long red vine licorice',
#  'pimm no gin base liqueur',
#  'pinch crush red pepper flake',
#  'pinch ground cayenne pepper optional',
#  'pinch salt ground black pepper',
#  'pinch salt ground white pepper',
#  'pint canning jar lid ring',
#  'pint french vanilla ice cream',
#  'pint part skim ricotta cheese',
#  'pizza sauce such contadina',
#  'plain fat free greek yogurt',
#  'poppy seed salad dressing',
#  'pork shoulder roast butt roast',
#  'prepared dough single crust pie',
#  'process cheese food eg velveeta',
#  'process cheese food such velveeta',
#  'process cheese such velveeta',
#  'rare deli roast beef',
#  'recipe pastry double crust pie',
#  'recipe pastry single crust pie',
#  'recipe perfect parmesan pizza dough',
#  'red green candy coat chocolate',
#  'red green candy sprinkle optional',
#  'reduce fat cheddar cheese',
#  'reduce sodium soy sauce',
#  'roast garlic parmesan cheese sauce',
#  'roasted red pepper pack oil',
#  'round sandwich roll hamburger roll',
#  'scoop chocolate flavor protein powder',
#  'scoop vanilla ice cream',
#  'scoop vanilla whey protein powder',
#  'seafood seasoning such old bay',
#  'season dry bread crumb',
#  'semi sweet chocolate chip',
#  'sheet reynolds aluminum foil',
#  'shred american cheddar cheese blend',
#  'shred cheddar colby jack cheese',
#  'shred cheddar monterey cheese blend',
#  'shred cheddar style soy cheese',
#  'shred colby monterey jack cheese',
#  'shred extra sharp cheddar cheese',
#  'shred low fat cheddar cheese',
#  'shred mexican style cheese blend',
#  'shred monterey jack cheese',
#  'shred monterey jack cheese optional',
#  'shred part skim mozzarella cheese',
#  'shred reduce fat cheddar cheese',
#  'shred sharp cheddar cheese',
#  'shred sharp white cheddar cheese',
#  'skinless boneless chicken breast half',
#  'slice american cheese such kraft',
#  'slice cook deli turkey breast',
#  'slice country style french bread',
#  'slice deli slice corned beef',
#  'slice deli turkey meat',
#  'slice extra sharp provolone cheese',
#  'slice fresh mushroom optional',
#  'slice garlic rosemary focaccia bread',
#  'slice green bell pepper',
#  'slice green olive optional',
#  'slice gruyere swiss cheese slice',
#  'slice mesquite smoke turkey breast',
#  'slice pepperoncini pepper optional',
#  'slice pit ripe olive optional',
#  'slice process sharp cheddar cheese',
#  'small fresh mozzarella ball ciliegine',
#  'small fresh red chile pepper',
#  'small hot green chile pepper',
#  'small pearlini fresh mozzarella ball',
#  'small pit black olive',
#  'soft bread crumb optional',
#  'solid pack pumpkin puree',
#  'solid white tuna pack water',
#  'spicy italian sausage brown',
#  'spicy tomato vegetable juice cocktail',
#  'sprig fresh mint leaf garnish',
#  'sun dry tomato dressing',
#  'sun dry tomato oil pack',
#  'sun dry tomato pesto',
#  'sweet sour cocktail mix',
#  'tequila measure empty limeade',
#  'tequila such % blue agave',
#  'thai chili sauce hot sauce',
#  'thai sweet red chili sauce',
#  'thick ring green bell pepper',
#  'thick slice french italian bread',
#  'thick slice whole wheat bread',
#  'thin pizza crust homemade prepared',
#  'thin slice deli turkey breast',
#  'tomato base chili sauce',
#  'tomato clam juice cocktail',
#  'tomato green chile such ro*tel',
#  'tomato vegetable juice cocktail',
#  'triple sec orange flavor liqueur',
#  'tub cool whip whip topping',
#  'tub sun dry tomato pesto',
#  'turbinado sugar such sugar raw',
#  'unbaked deep dish pie crust',
#  'uncooked long grain white rice',
#  'uncooked tri color spiral pasta',
#  'uncooked whole grain elbow macaroni',
#  'unsweetened apple juice concentrate',
#  'vanilla flavor vodka such',
#  'vanilla yogurt vanilla freeze yogurt',
#  'vital wheat gluten optional',
#  'warm water degree c',
#  'whip cream garnish optional'}

# %%
outputs[6]
# Out:
# {'baked whole wheat regular pizza crust',
#  'bone pork shoulder blade roast',
#  'bottle mexican beer such corona',
#  'bottle tomato vegetable juice cocktail',
#  'box red velvet cake mix',
#  'box vanilla wafer cookie such nilla',
#  'candy coat milk chocolate piece such',
#  'cayenne pepper sauce such frank redhot',
#  'chocolate sandwich cookie such oreo',
#  'chop roasted honey roast peanut',
#  'chop sun dry tomato olive oil',
#  'clear plastic latex free disposable glove',
#  'coffee flavor liqueur such kahlua',
#  'container part skim ricotta cheese',
#  'cream coconut such coco lopez',
#  'creamy salad dressing such miracle whip',
#  'creole seasoning blend such link footnote',
#  'crush chocolate sandwich cookie such oreo',
#  'dash crush red pepper flake optional',
#  'dash hot pepper sauce such tabasco',
#  'dash hot sauce such frank redhot',
#  'dash hot sauce such tabasco optional',
#  'dash pepper sauce such red hot',
#  'dry mustard powder such colman',
#  'envelope reduce sodium taco seasoning mix',
#  'extra virgin olive oil drizzle',
#  'fluid amaretto almond flavor liqueur',
#  'fluid bottle buffalo wing sauce',
#  'fluid dairy vanilla flavor creamer',
#  'fluid vanilla flavor vodka optional',
#  'free condense cream mushroom soup',
#  'gluten free pasta such barilla',
#  'herb season dry bread stuffing mix',
#  'high protein crisp rice wheat cereal',
#  'hot chile paste such sambal oelek',
#  'hot dog beef pork frankfurter',
#  'hot pepper sauce such frank redhot',
#  'instant coffee granule hot water',
#  'italian style dry bread crumb',
#  'italian style season bread crumb',
#  'jar chocolate hazelnut spread such nutella',
#  'jar tomato basil pasta sauce',
#  'jigger coconut flavor rum such',
#  'jigger irish cream liqueur such',
#  'jigger pumpkin flavor liqueur such',
#  'jigger vanilla flavor vodka such',
#  'kahlua other coffee flavor liqueur',
#  'karo light dark corn syrup',
#  'large leek white pale green part',
#  'lemon lime flavor carbonate beverage',
#  'lemon lime soda such sprite',
#  'loaf frozen whole wheat bread dough',
#  'loaf process cheese food such velveeta',
#  'marshmallow cream such marshmallow fluff',
#  'mexican style corn red green pepper',
#  'mexican style shred cheese blend',
#  'milk chocolate candy kiss such hershey',
#  'mini semi sweet chocolate chip',
#  'mini vanilla wafer cookie such nilla',
#  'miniature chocolate cover peanut butter',
#  'miniature marshmallow such kraft jet puffed',
#  'montreal style steak seasoning optional',
#  'nestle toll house semi sweet chocolate',
#  'oil pack sun dry tomato',
#  'orange flavor liqueur such cointreau',
#  'package 12-inch size italian pizza crust',
#  'package baker semi sweet baking chocolate',
#  'package beef onion soup mix',
#  'package butter pecan cake mix',
#  'package butterball turkey dinner sausage',
#  'package buttery round cracker such ritz',
#  'package candy coat chocolate piece',
#  'package chocolate sandwich cookie creme fill',
#  'package cinnamon red hot candy',
#  'package corn bread muffin mix',
#  'package crescent roll dough such pillsbury',
#  'package dark chocolate cake mix',
#  'package devil food cake mix',
#  'package dry onion soup mix',
#  'package dry ranch salad dressing mix',
#  'package dry ranch style dressing mix',
#  'package dry taco seasoning mix',
#  'package fresh frozen pizza dough',
#  'package frozen pepper onion fry mix',
#  'package frozen philly beef steak',
#  'package frozen puff pastry sheet',
#  'package fruit flavor jell o mix',
#  'package german chocolate cake mix',
#  'package hillshire farm beef smoke sausage',
#  'package lime flavor jell o mix',
#  'package macaroni cheese dinner mix',
#  'package mild taco seasoning mix',
#  'package moist white cake mix',
#  'package pastry double crust pie',
#  'package pillsbury classic traditional fudge',
#  'package process cheese food such velveeta',
#  'package refrigerated pizza dough such',
#  'package refrigerated pizza dough such trader',
#  'package refrigerated sugar cookie dough',
#  'package restaurant style tortilla chip',
#  'package shred mozzarella cheddar pizza cheese',
#  'package shred reduce fat cheddar cheese',
#  'package small whole wheat pasta shell',
#  'package strawberry flavor jell o mix',
#  'package thin rice noodle vermicelli style',
#  'package uncooked tri color rotini pasta',
#  'package uncooked tri color spiral pasta',
#  'package unseasoned dry bread stuffing mix',
#  'package vegetarian ground beef substitute',
#  'package white cheddar macaroni cheese mix',
#  'packet dry brown gravy mix',
#  'packet peach cream flavor instant oatmeal',
#  'pasteurize egg white liquid egg substitute',
#  'pie fill other filling choice',
#  'pinch salt ground black pepper optional',
#  'pinot noir other dry red wine',
#  'pizza dough footnote recipe link',
#  'prebaked pizza crust such boboli',
#  'process cheese food eg velveeta',
#  'process cheese food such velveeta',
#  'recipe pastry 9-inch double crust pie',
#  'scoop vanilla flavor whey protein powder',
#  'shred cheddar monterey jack cheese blend',
#  'shred extra sharp orange cheddar cheese',
#  'shred extra sharp white cheddar cheese',
#  'shred hot pepper monterey jack cheese',
#  'shred mexican style process cheese food',
#  'shred pepper jack cheese spice paprika',
#  'shred pepper jack monterey jack cheese',
#  'shred reduce fat monterey jack cheese',
#  'sleeve buttery round cracker such ritz',
#  'slice cook deli roast beef',
#  'slice process cheese food such velveeta',
#  'small ball fresh mozzarella cheese label',
#  'small jalapeno pepper seed thick matchstick',
#  'smoke sausage such conecuh ©',
#  'spice % pure bourbon vanilla extract',
#  'strawberry puree frozen sweeten strawberry',
#  'tear kale leaf bite size piece',
#  'thick slice deli chicken breast meat',
#  'thin prebaked whole wheat pizza crust',
#  'thin strip green bell pepper optional',
#  'tomato green chile pepper such ro*tel',
#  'tomato puree such contadina tomato puree',
#  'triple sec orange flavor liqueur',
#  'tropical fruit flavor jell o mix',
#  'tub philadelphia chive onion cream cheese',
#  'unbaked pie crust footnote recipe link',
#  'uncooked glutinous white rice sushi rice',
#  'uncooked regular long grain white rice',
#  'warm milk f/45 degree c',
#  'warm water f/45 degree c',
#  'well marble beef steak type',
#  'wheat barley nugget cereal grape',
#  'whole berry cranberry sauce 16-ounce can'}

# %%
writeres("unit", all_units)
